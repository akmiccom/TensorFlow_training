# %%
import glob
import imageio
# import imageio.v2 as imageio
import PIL
import tensorflow_docs.vis.embed as embed

# %%
anim_file = "dcgan.gif"

with imageio.get_writer(anim_file, mode="I") as writer:
    filenames = glob.glob("../images/imega*.png")
    filenames = sorted(filenames)
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)
# Out:
# C:\Users\JY810251\AppData\Local\Temp\ipykernel_2732\4188407072.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# C:\Users\JY810251\AppData\Local\Temp\ipykernel_2732\4188407072.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
from PIL import Image, ImageDraw

files = glob.glob("../images/imega*")
# print(len(files))

images = []
for file in files:
    im = Image.open(file)
    images.append(im)

images[0].save(
    "../images/test.gif",
    save_all=True,
    append_images=images[1:],
    optimize=False,
    duration=250,
    loop=0,
)
